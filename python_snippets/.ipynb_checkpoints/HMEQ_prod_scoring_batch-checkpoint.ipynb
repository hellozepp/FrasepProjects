# %%
import swat
import os

# %% [markdown]
# # Connect to the CAS server

# %%
os.environ['CAS_CLIENT_SSL_CA_LIST'] = '/opt/sas/viya/config/etc/SASSecurityCertificateFramework/cacerts/trustedcerts.pem'
s = swat.CAS('frasepviya35smp.cloud.com', 5570)
# Define default session caslib
s.sessionprop.setsessopt(caslib='public',metrics='true')
# Out:
# NOTE: 'Public' is now the active caslib.
# NOTE: Action 'sessionProp.setSessOpt' used (Total process time):
# NOTE:       real time               0.000264 seconds
# NOTE:       cpu time                0.000239 seconds (90.53%)
# NOTE:       total nodes             1 (16 cores)
# NOTE:       total memory            125.75G
# NOTE:       memory                  262.06K (0.00%)
# + Elapsed: 0.000264s, user: 0.000159s, sys: 8e-05s, mem: 0.256mb

# %%
# Name the existing CAS table to be used
indata = 'HMEQ_NEW'

# Declare python CASTable view on CAS in-memory table
castbl = s.CASTable(indata)

# %%
castbl.shape
# Out:
# (5960, 15)

# %%
castbl.describe()
# Out:
#           Unique_ID          BAD          LOAN        MORTDUE          VALUE          YOJ        DEROG       DELINQ        CLAGE         NINQ         CLNO   _PARTIND_      DEBTINC
# count   5960.000000  5960.000000   5960.000000    5442.000000    5848.000000  5445.000000  5252.000000  5380.000000  5652.000000  5450.000000  5738.000000  5960.00000  5960.000000
# mean   24931.192785     0.199497  18607.969799   73760.817200  101776.048741     8.922268     0.254570     0.449442   179.766275     1.186055    21.296096     0.80000    33.779915
# std    14413.358335     0.399656  11207.480417   44457.609458   57385.775334     7.573982     0.846047     1.127266    85.810092     1.728675    10.138933     0.60005     7.632713
# min      101.000000     0.000000   1100.000000    2063.000000    8000.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.00000     0.524499
# 25%    12502.500000     0.000000  11100.000000   46268.000000   66069.000000     3.000000     0.000000     0.000000   115.103197     0.000000    15.000000     0.00000    30.757681
# 50%    24904.500000     0.000000  16300.000000   65019.000000   89235.500000     7.000000     0.000000     0.000000   173.466667     1.000000    20.000000     1.00000    33.779915
# 75%    37306.500000     0.000000  23300.000000   91491.000000  119831.500000    13.000000     0.000000     0.000000   231.574834     2.000000    26.000000     1.00000    37.950190
# max    55401.000000     1.000000  89900.000000  399550.000000  855909.000000    41.000000    10.000000    15.000000  1168.233561    17.000000    71.000000     2.00000   203.312149

# %%
s.loadactionset('modelPublishing')

s.dropTable(caslib="casuser", name='TMP_SCORED_HMEQ_DATA_swat', quiet="true")
s.modelPublishing.runModelLocal(
    outTable=dict(caslib="casuser", name="TMP_SCORED_HMEQ_DATA_swat"),
    intable=dict(caslib="public", name="HMEQ_NEW"),
    modelTable=dict(caslib="public", name="sas_model_table"),
    modelName="GBT_Model_sklearn")
# Out:
# NOTE: Executing action 'builtins.loadActionSet'.
# NOTE: Added action set 'modelPublishing'.
# NOTE: Action 'builtins.loadActionSet' used (Total process time):
# NOTE:       real time               0.001392 seconds
# NOTE:       cpu time                0.001362 seconds (97.84%)
# NOTE:       total nodes             1 (16 cores)
# NOTE:       total memory            125.75G
# NOTE:       memory                  226.94K (0.00%)
# NOTE: Executing action 'table.dropTable'.
# NOTE: Action 'table.dropTable' used (Total process time):
# NOTE:       real time               0.000548 seconds
# NOTE:       cpu time                0.000490 seconds (89.42%)
# NOTE:       total nodes             1 (16 cores)
# NOTE:       total memory            125.75G
# NOTE:       memory                  281.97K (0.00%)
# NOTE: Executing action 'modelPublishing.runModelLocal'.
# NOTE: Running 'modelPublishing' action set with 0 workers.
# NOTE: Added action set 'ds2'.
# NOTE: Executing action 'ds2.runModel'.
#          1        package _F8D2702C58C14AB889832B9AC941758 / overwrite=yes;
#          2            dcl package pymas py;
#          3            dcl package logger logr('App.tk.MAS');
#          4            dcl varchar(67108864) character set utf8 pycode;
#          5            dcl int revision;
#          6
#          7            method init();
#          8
#          9                dcl integer rc;
#          10               if null(py) then do;
#          11                   py = _new_ pymas();
#          12                   rc = py.useModule('F8D2702C58C14AB889832B9AC9417586', 1);
#          13                   if rc then do;
#          14                       rc = py.appendSrcLine('try:');
#          15                       rc = py.appendSrcLine('    import pickle, base64');
#          16                       rc = py.appendSrcLine('    bytes = b"..."');
#          17                       rc = py.appendSrcLine('    obj = pickle.loads(base64.b64decode(bytes))');
#          18                       rc = py.appendSrcLine('    _compile_error = None');
#          19                       rc = py.appendSrcLine('except Exception as e:');
#          20                       rc = py.appendSrcLine('    _compile_error = e');
#          21                       rc = py.appendSrcLine('');
#          22                       rc = py.appendSrcLine('def _wSwKXy8NacZcYmUxpdxe():');
#          23                       rc = py.appendSrcLine('    "Output: result, msg"');
#          24                       rc = py.appendSrcLine('    result = None');
#          25                       rc = py.appendSrcLine('    msg = None');
#          26                       rc = py.appendSrcLine('    try:');
#          27                       rc = py.appendSrcLine('        global _compile_error');
#          28                       rc = py.appendSrcLine('        if _compile_error is not None:');
#          29                       rc = py.appendSrcLine('            raise _compile_error');
#          30                       rc = py.appendSrcLine('        import numpy as np');
#          31                       rc = py.appendSrcLine('        import pandas as pd');
#          32                       rc = py.appendSrcLine('');
#          33                       rc = py.appendSrcLine('        input_array = np.array([]).reshape((1, -1))');
#          34                       rc = py.appendSrcLine('        columns = []');
#          35                       rc = py.appendSrcLine('        input_df = pd.DataFrame(data=input_array, columns=columns)');
#          36                       rc = py.appendSrcLine('        result = obj.predict(input_df)');
#          37                       rc = py.appendSrcLine('        result = tuple(result.ravel()) if hasattr(result, "ravel") else tuple(result)');
#          38                       rc = py.appendSrcLine('        if len(result) == 0:');
#          39                       rc = py.appendSrcLine('            result = tuple(None for i in range(1))');
#          40                       rc = py.appendSrcLine('        elif "numpy" in str(type(result[0])):');
#          41                       rc = py.appendSrcLine('            result = tuple(np.asscalar(i) for i in result)');
#          42                       rc = py.appendSrcLine('    except Exception as e:');
#          43                       rc = py.appendSrcLine('        from traceback import format_exc');
#          44                       rc = py.appendSrcLine('        msg = str(e) + format_exc()');
#          45                       rc = py.appendSrcLine('        if result is None:');
#          46                       rc = py.appendSrcLine('            result = tuple(None for i in range(1))');
#          47                       rc = py.appendSrcLine('    return result + (msg, )');
#          48                       rc = py.appendSrcLine('');
#          49                       rc = py.appendSrcLine('def _bQi0dt1qNZF5nxT3Le80():');
#          50                       rc = py.appendSrcLine('    "Output: result, msg"');
#          51                       rc = py.appendSrcLine('    result = None');
#          52                       rc = py.appendSrcLine('    msg = None');
#          53                       rc = py.appendSrcLine('    try:');
#          54                       rc = py.appendSrcLine('        global _compile_error');
#          55                       rc = py.appendSrcLine('        if _compile_error is not None:');
#          56                       rc = py.appendSrcLine('            raise _compile_error');
#          57                       rc = py.appendSrcLine('        import numpy as np');
#          58                       rc = py.appendSrcLine('        import pandas as pd');
#          59                       rc = py.appendSrcLine('');
#          60                       rc = py.appendSrcLine('        input_array = np.array([]).reshape((1, -1))');
#          61                       rc = py.appendSrcLine('        columns = []');
#          62                       rc = py.appendSrcLine('        input_df = pd.DataFrame(data=input_array, columns=columns)');
#          63                       rc = py.appendSrcLine('        result = obj.predict_proba(input_df)');
#          64                       rc = py.appendSrcLine('        result = tuple(result.ravel()) if hasattr(result, "ravel") else tuple(result)');
#          65                       rc = py.appendSrcLine('        if len(result) == 0:');
#          66                       rc = py.appendSrcLine('            result = tuple(None for i in range(1))');
#          67                       rc = py.appendSrcLine('        elif "numpy" in str(type(result[0])):');
#          68                       rc = py.appendSrcLine('            result = tuple(np.asscalar(i) for i in result)');
#          69                       rc = py.appendSrcLine('    except Exception as e:');
#          70                       rc = py.appendSrcLine('        from traceback import format_exc');
#          71                       rc = py.appendSrcLine('        msg = str(e) + format_exc()');
#          72                       rc = py.appendSrcLine('        if result is None:');
#          73                       rc = py.appendSrcLine('            result = tuple(None for i in range(1))');
#          74                       rc = py.appendSrcLine('    return result + (msg, )');
#          75                       pycode = py.getSource();
#          76                       revision = py.publish(pycode, 'F8D2702C58C14AB889832B9AC9417586');
#          77                       if revision lt 1 then do;
#          78                           logr.log('e', 'py.publish() failed.');
#          79                           rc = -1;
#          80                       end;
#          81                   end;
#          82               end;
#          83           end;
#          84
#          85           method predict(
#          86               in_out double result
#          87               );
#          88
#          89               dcl integer rc;
#          90               dcl varchar(4068) msg;
#          91               rc = py.useMethod('_wSwKXy8NacZcYmUxpdxe');
#          92               if rc then return;
#          93               rc = py.execute();    if rc then return;
#          94               result = py.getDouble('result');
#          95               msg = py.getString('msg');
#          96               if not null(msg) then logr.log('e', 'Error executing Python function "predict": $s', msg);
#          97           end;
#          98
#          99           method predict_proba(
#          100              in_out double result
#          101              );
#          102
#          103              dcl integer rc;
#          104              dcl varchar(4068) msg;
#          105              rc = py.useMethod('_bQi0dt1qNZF5nxT3Le80');
#          106              if rc then return;
#          107              rc = py.execute();    if rc then return;
#          108              result = py.getDouble('result');
#          109              msg = py.getString('msg');
#          110              if not null(msg) then logr.log('e', 'Error executing Python function "predict_proba": $s', msg);
#          111          end;
#          112
#          113      endpackage;
#          114
#          115      thread pyMasThread / inline;
#          116        dcl package _F8D2702C58C14AB889832B9AC941758 pythonPackage();
#          117      dcl double result;
#          118        method run();
#          119          set "public"."HMEQ_NEW";
#          120
#          121          pythonPackage.init();
#          122          pythonPackage.predict(result);
#          123          output;
#          124        end;
#          125      endthread;
#          126      data "CASUSER(viyademo01)"."TMP_SCORED_HMEQ_DATA_swat";
#          127        dcl thread pyMasThread t;
#          128        method run();
#          129          set from t;
#          130          output;
#          131        end;
# NOTE: Created package _f8d2702c58c14ab889832b9ac941758 in data set "public"._f8d2702c58c14ab889832b9ac941758.
# NOTE: Running THREAD program on all nodes
# NOTE: Running DATA program on all nodes
# NOTE: Execution succeeded. 5960 rows affected.
# NOTE: Action 'ds2.runModel' used (Total process time):
# NOTE:       real time               4.765481 seconds
# NOTE:       cpu time                1.673568 seconds (35.12%)
# NOTE:       total nodes             1 (16 cores)
# NOTE:       total memory            125.75G
# NOTE:       memory                  73.29M (0.06%)
# NOTE: Execution of model 'GBT_Model_sklearn' succeeded.
# NOTE: Action 'modelPublishing.runModelLocal' used (Total process time):
# NOTE:       real time               4.773003 seconds
# NOTE:       cpu time                1.680991 seconds (35.22%)
# NOTE:       total nodes             1 (16 cores)
# NOTE:       total memory            125.75G
# NOTE:       memory                  73.29M (0.06%)
# + Elapsed: 4.77s, user: 1.06s, sys: 0.624s, mem: 73.3mb

# %%
# Declare python CASTable view on CAS in-memory table
scoredCastbl = s.CASTable(caslib="casuser", name="TMP_SCORED_HMEQ_DATA_swat")

scoredCastbl.head(50)
# Out:
# Selected Rows from Table TMP_SCORED_HMEQ_DATA_SWAT
#
#     result  Unique_ID  BAD    LOAN   MORTDUE     VALUE   REASON      JOB   YOJ  DEROG  DELINQ       CLAGE  NINQ  CLNO  _PARTIND_    DEBTINC
# 0      NaN      101.0  1.0  1100.0   25860.0   39025.0  HomeImp    Other  10.5    0.0     0.0   94.366667   1.0   9.0        1.0  33.779915
# 1      NaN      201.0  1.0  1300.0   70053.0   68400.0  HomeImp    Other   7.0    0.0     2.0  121.833333   0.0  14.0        0.0  33.779915
# 2      NaN      301.0  1.0  1500.0   13500.0   16700.0  HomeImp    Other   4.0    0.0     0.0  149.466667   1.0  10.0        1.0  33.779915
# 3      NaN      401.0  1.0  1500.0       NaN       NaN                     NaN    NaN     NaN         NaN   NaN   NaN        1.0  33.779915
# 4      NaN      501.0  0.0  1700.0   97800.0  112000.0  HomeImp   Office   3.0    0.0     0.0   93.333333   0.0  14.0        1.0  33.779915
# 5      NaN      601.0  1.0  1700.0   30548.0   40320.0  HomeImp    Other   9.0    0.0     0.0  101.466002   1.0   8.0        1.0  37.113614
# 6      NaN      701.0  1.0  1800.0   48649.0   57037.0  HomeImp    Other   5.0    3.0     2.0   77.100000   1.0  17.0        1.0  33.779915
# 7      NaN      801.0  1.0  1800.0   28502.0   43034.0  HomeImp    Other  11.0    0.0     0.0   88.766030   0.0   8.0        1.0  36.884894
# 8      NaN      901.0  1.0  2000.0   32700.0   46740.0  HomeImp    Other   3.0    0.0     2.0  216.933333   1.0  12.0        1.0  33.779915
# 9      NaN     1001.0  1.0  2000.0       NaN   62250.0  HomeImp    Sales  16.0    0.0     0.0  115.800000   0.0  13.0        1.0  33.779915
# 10     NaN     1101.0  1.0  2000.0   22608.0       NaN                    18.0    NaN     NaN         NaN   NaN   NaN        2.0  33.779915
